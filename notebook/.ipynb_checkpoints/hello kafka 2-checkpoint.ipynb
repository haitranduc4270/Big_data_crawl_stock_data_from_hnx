# %%
# !pip install kafka-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 895.2 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import json
from kafka import KafkaConsumer

consumer = KafkaConsumer(bootstrap_servers='kafka:9092')
consumer.subscribe(['consumer_topic', 'default_topic'])

while 1:
  for msg in consumer:
    print(msg)
    # print (json.loads(msg.value.decode('utf-8')))
# Out:
# ConsumerRecord(topic='default_topic', partition=0, offset=83, timestamp=1672671381517, timestamp_type=0, key=None, value=b'{"data_dir": "hdfs://namenode:9000/project20221/raw/ssiDataApi.csv", "config_dir": "hdfs://namenode:9000/project20221/config/stock_data_ssi", "topic": "default_topic", "time_stamp": "Mon Jan  2 14:56:21 2023"}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=209, serialized_header_size=-1)
# ConsumerRecord(topic='default_topic', partition=0, offset=84, timestamp=1672671382245, timestamp_type=0, key=None, value=b'{"data_dir": "hdfs://namenode:9000/project20221/raw/ssiDataApi.csv", "config_dir": "hdfs://namenode:9000/project20221/config/stock_data_ssi", "topic": "default_topic", "time_stamp": "Mon Jan  2 14:56:22 2023"}', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=209, serialized_header_size=-1)
# ...
